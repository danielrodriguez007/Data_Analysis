# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/WordCloud_Petro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
from wordcloud import WordCloud 
from wordcloud import ImageColorGenerator 
from wordcloud import STOPWORDS
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Discurso_Petro_ONU.csv', names=['text'])
data
# Out:
#                                                  text
# 0   Vengo de uno de los tres países más bellos de ...
# 1                                                 NaN
# 2   Allí hay una explosión de vida. Miles de espec...
# 3                                                 NaN
# 4   Mi país no solo es bello, es también violento....
# ..                                                ...
# 68  Solo cambien deuda por vida, por naturaleza. L...
# 69                                                NaN
# 70  Desde América Latina, convocamos a Ucrania y R...
# 71                                                NaN
# 72  Estamos en guerra, también, con el planeta. Si...
#
# [73 rows x 1 columns]

# %%
data2 = data.dropna()
data2.head()
# Out:
#                                                 text
# 0  Vengo de uno de los tres países más bellos de ...
# 2  Allí hay una explosión de vida. Miles de espec...
# 4  Mi país no solo es bello, es también violento....
# 6  ¿Quién o qué es el responsable de ahogar la vi...
# 8  Mi país es bello porque tiene la Selva Amazóni...

# %%
import nltk
nltk.download('stopwords')

text = " ".join(i for i in data2.text)
stopwords = set(stopwords.words('spanish'))
wordcloud = WordCloud(stopwords=stopwords, background_color='black').generate(text) 
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
