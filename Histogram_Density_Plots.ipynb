# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Histogram_Density_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()

# %%
#Plotting a histogram
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size = 2000)
data = pd.DataFrame(data, columns=['x', 'y'])
plt.figure(figsize=(10,8))
plt.hist(data['x'], alpha = 0.5) 
plt.hist(data['y'], alpha = 0.5)
plt.show()

# %%
#Plotting Density graph

plt.figure(figsize=(10,8))
sns.kdeplot(data['x'], shade = True)
sns.kdeplot(data['y'], shade = True)
plt.show()

# %%
#Visualizing both plots Histogram and Density

plt.figure(figsize=(10, 8))
sns.distplot(data['x'])
sns.displot(data['y'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data2 = np.array([[60, 61, 87, 86],[64, 65, 86, 89],[68,69,89,88], [62,63,88,85]])
df = pd.DataFrame(data2, columns=["1","2","3", "4"])
plt.figure(figsize=(10,8))
sns.kdeplot(df['1'], shade = True, label = '1')
sns.kdeplot(df['2'], shade = True, label = '2')
sns.kdeplot(df['3'], shade = True, label = '3')
sns.kdeplot(df['4'], shade = True, label = '4')
plt.legend()
plt.title("Looking how to works Density plots")
plt.xlabel("Quantity of samples")
plt.show()
print(df)
# Out:
#     1   2   3   4
# 0  60  61  87  86
# 1  64  65  86  89
# 2  68  69  89  88
# 3  62  63  88  85

# %%
data2 = np.array([[60, 61, 87, 86],[64, 65, 86, 89],[68,69,89,88], [62,63,88,85]])
df = pd.DataFrame(data2, columns=["1","2","3", "4"])
plt.figure(figsize=(10,8))
sns.distplot(df['1'])
sns.distplot(df['2'])
sns.distplot(df['3'])
sns.distplot(df['4'])
plt.legend()
plt.title("Looking how to works Density plots")
plt.xlabel("Quantity of samples")
plt.show()
print(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
data3 = np.array([[35,78,12,99],[67,55,33,76],[22,15,65,97],[39,72,49,11],[2,32,67,60]])
index = np.array(["Enero", "Febrero", "Marzo", "Abril"])
df2 = pd.DataFrame(data3,columns = index)

#plt.figure(figsize=(10,8))
sns.kdeplot(df2['Enero'], shade = True, label = index[0])
sns.kdeplot(df2['Febrero'], shade = True, label = index[1])
sns.kdeplot(df2['Marzo'], shade = True, label = index[2])
sns.kdeplot(df2['Abril'], shade = True, label = index[3])
plt.legend()

print(df2)
# Out:
#    Enero  Febrero  Marzo  Abril
# 0     35       78     12     99
# 1     67       55     33     76
# 2     22       15     65     97
# 3     39       72     49     11
# 4      2       32     67     60

# %%
np.random.seed(0)

data3 = np.round(np.random.rand(2000,4)*10, 0)
index = np.array(["Enero", "Febrero", "Marzo", "Abril"])
df2 = pd.DataFrame(data3,columns = index)

plt.figure(figsize=(10,8))
plt.hist(df2['Febrero'], label = index[0], width = 26)
#plt.hist(df2['Febrero'], label = index[1])
#plt.hist(df2['Marzo'], label = index[2])
#plt.hist(df2['Abril'], label = index[3])
plt.legend()

print(df2)
# Out:
#       Enero  Febrero  Marzo  Abril
# 0       5.0      7.0    6.0    5.0
# 1       4.0      6.0    4.0    9.0
# 2      10.0      4.0    8.0    5.0
# 3       6.0      9.0    1.0    1.0
# 4       0.0      8.0    8.0    9.0
# ...     ...      ...    ...    ...
# 1995    3.0      6.0    3.0    7.0
# 1996    4.0      8.0    5.0    6.0
# 1997    9.0      4.0    6.0    2.0
# 1998    7.0      2.0    7.0    9.0
# 1999    9.0      8.0    5.0    8.0
#
# [2000 rows x 4 columns]

# %% [markdown]
# data4 = [13,56,78,34,69,63,45,41,44,12,32,98,76,23,26,65,25,87,67,13,54,23]
#
# plt.figure(figsize=(10,8))
# plt.hist(data4, color="#444444")
# plt.xlabel("Random Numbers")
# plt.ylabel("Frecuency")
# plt.title("Random Histogram")
# plt.show()

# %%
data4 = [13,56,78,34,69,63,45,41,44,12,32,98,76,23,26,65,25,87,67,13,54,23] 
median = np.median(data4)

plt.figure(figsize=(10,8)) 
plt.hist(data4, color="#444444", bins=10)
plt.axvline(median, color="#fc4f30", linewidth=3, label="Ages Median")
plt.legend()
plt.title("Histogram of ages")
plt.xlabel("Ages")
plt.ylabel("Frequency")
plt.show()
