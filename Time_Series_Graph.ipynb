# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Time_Series_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 787 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import pandas as pd 
import yfinance as yf
import datetime 
from datetime import date, timedelta
import matplotlib.pyplot as plt 
today = date.today()


d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=360) 
d2 = d2.strftime("%Y-%m-%d") 
start_date = d2

data = yf.download('NTDOY',
                   start=start_date,
                   end=end_date,
                   progress=False)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2021-09-24  61.320000  61.320000  60.279999  60.759998  60.759998   282400
# 2021-09-27  61.250000  61.290001  60.419998  60.740002  60.740002   193400
# 2021-09-28  60.380001  60.380001  58.049999  58.169998  58.169998   716200
# 2021-09-29  59.450001  59.919998  59.000000  59.009998  59.009998   678800
# 2021-09-30  60.250000  60.439999  58.799999  59.250000  59.250000  1049700

# %%
import plotly.express as px 
figure = px.line(data, x=data.index, y='Close')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=360) 
d2 = d2.strftime("%Y-%m-%d") 
start_date = d2

data = yf.download('BTC-USD',
                   start=start_date,
                   end=end_date,
                   progress=False)
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-09-24  44894.300781  45080.492188  40936.558594  42839.750000
# 2021-09-25  42840.890625  42996.257812  41759.921875  42716.593750
# 2021-09-26  42721.628906  43919.300781  40848.460938  43208.539062
# 2021-09-27  43234.183594  44313.246094  42190.632812  42235.730469
# 2021-09-28  42200.898438  42775.144531  40931.664062  41034.542969
#
#                Adj Close       Volume
# Date
# 2021-09-24  42839.750000  42839345714
# 2021-09-25  42716.593750  31604717236
# 2021-09-26  43208.539062  30661222077
# 2021-09-27  42235.730469  30980029059
# 2021-09-28  41034.542969  30214940550

# %%
px.line(data, x=data.index, y=['Open','Close'],title='Bitcoin Prices Chart')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
