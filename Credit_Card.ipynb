# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Credit_Card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Colab Notebooks/Kaggle'

# %%
# !kaggle datasets download -d arjunbhasin2013/ccdata
# Out:
# ...
#   0% 0.00/340k [00:00<?, ?B/s]
# 100% 340k/340k [00:00<00:00, 60.4MB/s]

# %%
# !unzip '/content/ccdata.zip' && rm '/content/ccdata.zip'
# Out:
# Archive:  /content/ccdata.zip
#   inflating: CC GENERAL.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023/CC GENERAL.csv')
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data = data.drop('CUST_ID', axis=1)

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
np.round(data.describe(),2)
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# count   8950.00            8950.00    8950.00           8950.00
# mean    1564.47               0.88    1003.20            592.44
# std     2081.53               0.24    2136.63           1659.89
# min        0.00               0.00       0.00              0.00
# 25%      128.28               0.89      39.64              0.00
# 50%      873.39               1.00     361.28             38.00
# 75%     2054.14               1.00    1110.13            577.40
# max    19043.14               1.00   49039.57          40761.25
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count                 8950.00       8950.00              8950.00
# mean                   411.07        978.87                 0.49
# std                    904.34       2097.16                 0.40
# min                      0.00          0.00                 0.00
# ...

# %%
data.shape
# Out:
# (8950, 17)

# %% [markdown]
# # **Normalization**

# %%
data_norm = (data-data.min())/(data.max()-data.min())
data_norm
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 3     0.087521           0.636364   0.030567          0.036775
# 4     0.042940           1.000000   0.000326          0.000393
# ...        ...                ...        ...               ...
# 8945  0.001496           1.000000   0.005936          0.000000
# 8946  0.001007           1.000000   0.006118          0.000000
# 8947  0.001229           0.833333   0.002945          0.000000
# 8948  0.000707           0.833333   0.000000          0.000000
# 8949  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %%
np.round(data_norm.describe(),2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# count  8950.00            8950.00    8950.00           8950.00
# mean      0.08               0.88       0.02              0.01
# std       0.11               0.24       0.04              0.04
# min       0.00               0.00       0.00              0.00
# 25%       0.01               0.89       0.00              0.00
# 50%       0.05               1.00       0.01              0.00
# 75%       0.11               1.00       0.02              0.01
# max       1.00               1.00       1.00              1.00
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count                 8950.00       8950.00              8950.00
# mean                     0.02          0.02                 0.49
# std                      0.04          0.04                 0.40
# min                      0.00          0.00                 0.00
# 25%                      0.00          0.00                 0.08
# ...

# %% [markdown]
# # **Looking for right quantity of clusters**

# %%
wcss = []

for i in range(1,11):
  kmeans = KMeans(n_clusters = i,max_iter = 300)
  kmeans.fit(data_norm)
  wcss.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-7350eede53db> in <module>
#       3 for i in range(1,11):
#       4   kmeans = KMeans(n_clusters = i,max_iter = 300)
# ----> 5   kmeans.fit(data_norm)
#       6   wcss.append(kmeans.inertia_)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1415         self._validate_params()
#    1416
# -> 1417         X = self._validate_data(
#    1418             X,
#    1419             accept_sparse="csr",
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     544             raise ValueError("Validation should be done on X, y or both.")
#     545         elif not no_val_X and no_val_y:
# --> 546             X = check_array(X, input_name="X", **check_params)
# ...
