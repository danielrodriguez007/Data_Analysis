# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Linear_regression_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
x = [7,9,11,13,15,17,19,21]
y = [1,17,21,35,37,59,50,50]

# %%
n = len(y)
x = np.array(x)
y = np.array(y)
sumx = sum(x)
sumy = sum(y)
sumxy = sum(x*y)
sumx2 = sum(x*x)
sumy2 = sum(y*y)
promx = sumx/n
promy = sumy/n

# %%
m = (sumx * sumy - n * sumxy)/(sumx**2 - n * sumx2)
b = promy - m * promx 
m,b
# Out:
# (3.7142857142857144, -18.25)

# %%
plt.figure(figsize=(10,10))
plt.plot(x, y, 'o', label='Data')
plt.plot(x, m*x+b, label='Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
sigmax = np.sqrt(sumx2/n - promx**2)
sigmay = np.sqrt(sumy2/n - promy**2)
sigmaxy = sumxy/n - promx*promy 

R2 = (sigmaxy/(sigmax*sigmay))**2
print(R2)
# Out:
# 0.86048423453287
