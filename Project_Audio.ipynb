# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Project_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install SpeechRecognition
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import library
import speech_recognition as sr

# Initialize recognizer class (for recognizing the speech) and open file to save transcription
t = open('/content/drive/MyDrive/Colab Notebooks/2023/Speech.txt', 'w+')
r = sr.Recognizer()

# Reading Audio file as source
# listening the audio file and store in audio_text variable

with sr.AudioFile('/content/drive/MyDrive/Colab Notebooks/2023/Test_Audio.wav') as source:
    
    audio_text = r.listen(source)
    
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        
        # using google speech recognition and save to txt file transcription
        text = r.recognize_google(audio_text)
        t.write(text +". ")
        print('Executed mate! ')
     
    except:
         print('Sorry.. run again...')
# Out:
# Executed mate!

# %%
import nltk
from wordcloud import WordCloud 
from wordcloud import ImageColorGenerator 
from wordcloud import STOPWORDS
from nltk.corpus import stopwords
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
with open('/content/drive/MyDrive/Colab Notebooks/2023/Speech.txt','r') as data:
  contents = data.read()

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color='black').generate(contents) 
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Text to be analyzed
text = "I walked through the abandoned streets, the only sound was the echo of my footsteps. I could feel the weight of emptiness surrounding me, as if the world had ceased to exist. The darkness was suffocating, and I couldn't shake the feeling of being watched. Suddenly, I heard a low growl behind me, and I turned to see a pair of glowing eyes staring back at me. Fear took over as I realized I was not alone, and I didn't know what was lurking in the shadows."

# Create a TextBlob object
blob = TextBlob(text)
# Get the sentiment polarity
sentiment_score = blob.sentiment.polarity


if sentiment_score > 0 :
  print('😊',"Positive with a sentiment score: ", np.round(sentiment_score,2))
elif sentiment_score < 0 :
  print('😡', "Negative with a sentiment score: ", np.round(sentiment_score,2))
else:
  print('😐', "Neutral with a sentiment score: ", np.round(sentiment_score,2))
# Out:
# 😡 Negative with a sentiment score:  -0.07
