# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id='2cdd2027043145eaad2b25adb580c2cd',
    client_secret='9fcbf3a7371b4ee6b064f95341569823',
    redirect_uri='http://127.0.0.1:9090',
    scope='user-top-read'
))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20,
                                              offset=0,
                                              time_range="short_term")
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KCph1z3jaSwhtwPzoYp6i'},
#       'href': 'https://api.spotify.com/v1/artists/5KCph1z3jaSwhtwPzoYp6i',
#       'id': '5KCph1z3jaSwhtwPzoYp6i',
#       'name': 'Body Count',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KCph1z3jaSwhtwPzoYp6i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ZSixj5BSyrt2fOvl7y4JA'},
#     'href': 'https://api.spotify.com/v1/albums/0ZSixj5BSyrt2fOvl7y4JA',
#     'id': '0ZSixj5BSyrt2fOvl7y4JA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d7cb25a30d1b17177e33539a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d7cb25a30d1b17177e33539a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d7cb25a30d1b17177e33539a',
#       'width': 64}],
#     'name': 'Manslaughter',
#     'release_date': '2014-06-09',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0ZSixj5BSyrt2fOvl7y4JA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KCph1z3jaSwhtwPzoYp6i'},
#      'href': 'https://api.spotify.com/v1/artists/5KCph1z3jaSwhtwPzoYp6i',
#      'id': '5KCph1z3jaSwhtwPzoYp6i',
#      'name': 'Body Count',
#      'type': 'artist',
#      'uri': 'spotify:artist:5KCph1z3jaSwhtwPzoYp6i'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 226089,
#    'explicit': True,
#    'external_ids': {'isrc': 'USYFZ1449307'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0q94IE56HxyHAsVnJ4bmPF'},
#    'href': 'https://api.spotify.com/v1/tracks/0q94IE56HxyHAsVnJ4bmPF',
#    'id': '0q94IE56HxyHAsVnJ4bmPF',
#    'is_local': False,
#    'name': 'Institutionalized 2014',
#    'popularity': 43,
#    'preview_url': None,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0q94IE56HxyHAsVnJ4bmPF'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Cdy6WLmVZ0Lwxq4gHBYcz'},
#     'href': 'https://api.spotify.com/v1/albums/1Cdy6WLmVZ0Lwxq4gHBYcz',
#     'id': '1Cdy6WLmVZ0Lwxq4gHBYcz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735eeeb898d246bbbd3027c401',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025eeeb898d246bbbd3027c401',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515eeeb898d246bbbd3027c401',
#       'width': 64}],
#     'name': 'Controlled By Hatred/Feel Like Shit... Deja-Vu',
#     'release_date': '1989-10-16',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:1Cdy6WLmVZ0Lwxq4gHBYcz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 280906,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10022499'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2hutxDJDHUWlYlHbq4oReO'},
#    'href': 'https://api.spotify.com/v1/tracks/2hutxDJDHUWlYlHbq4oReO',
#    'id': '2hutxDJDHUWlYlHbq4oReO',
#    'is_local': False,
#    'name': 'How Will I Laugh Tomorrow - Video Edit',
#    'popularity': 18,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0981e5dd95f0ddba7dea823bd50314a6978d0481?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2hutxDJDHUWlYlHbq4oReO'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#       'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#       'id': '2ye2Wgw4gimLv2eAKyk1NB',
#       'name': 'Metallica',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2iEqcqpNG3zKBZAmiZzuDv'},
#     'href': 'https://api.spotify.com/v1/albums/2iEqcqpNG3zKBZAmiZzuDv',
#     'id': '2iEqcqpNG3zKBZAmiZzuDv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738a3496e652b26ed82cc9b5ff',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028a3496e652b26ed82cc9b5ff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518a3496e652b26ed82cc9b5ff',
#       'width': 64}],
#     'name': 'Screaming Suicide',
#     'release_date': '2023-01-19',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:2iEqcqpNG3zKBZAmiZzuDv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#      'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#      'id': '2ye2Wgw4gimLv2eAKyk1NB',
#      'name': 'Metallica',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 330453,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMKHM2200018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0dwoX2gsjlRNa3rS40KFhQ'},
#    'href': 'https://api.spotify.com/v1/tracks/0dwoX2gsjlRNa3rS40KFhQ',
#    'id': '0dwoX2gsjlRNa3rS40KFhQ',
#    'is_local': False,
#    'name': 'Screaming Suicide',
#    'popularity': 65,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0dwoX2gsjlRNa3rS40KFhQ'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Cdy6WLmVZ0Lwxq4gHBYcz'},
#     'href': 'https://api.spotify.com/v1/albums/1Cdy6WLmVZ0Lwxq4gHBYcz',
#     'id': '1Cdy6WLmVZ0Lwxq4gHBYcz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735eeeb898d246bbbd3027c401',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025eeeb898d246bbbd3027c401',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515eeeb898d246bbbd3027c401',
#       'width': 64}],
#     'name': 'Controlled By Hatred/Feel Like Shit... Deja-Vu',
#     'release_date': '1989-10-16',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:1Cdy6WLmVZ0Lwxq4gHBYcz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 413773,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10025501'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Nd9G2HD0u3ca7PPtf0Olp'},
#    'href': 'https://api.spotify.com/v1/tracks/0Nd9G2HD0u3ca7PPtf0Olp',
#    'id': '0Nd9G2HD0u3ca7PPtf0Olp',
#    'is_local': False,
#    'name': 'Waking the Dead',
#    'popularity': 28,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e1ad8ec9485b91db41dfadf588cb032009f468ab?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:0Nd9G2HD0u3ca7PPtf0Olp'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/414jOqUfrq3k2QlAddNXfT'},
#     'href': 'https://api.spotify.com/v1/albums/414jOqUfrq3k2QlAddNXfT',
#     'id': '414jOqUfrq3k2QlAddNXfT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1886d236549fdbf0309b5ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1886d236549fdbf0309b5ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1886d236549fdbf0309b5ab',
#       'width': 64}],
#     'name': 'Lights...Camera...Revolution',
#     'release_date': '1990-07-02',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:414jOqUfrq3k2QlAddNXfT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 348093,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM19000164'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/203xxdlledLFnkqrUleD72'},
#    'href': 'https://api.spotify.com/v1/tracks/203xxdlledLFnkqrUleD72',
#    'id': '203xxdlledLFnkqrUleD72',
#    'is_local': False,
#    'name': "You Can't Bring Me Down",
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/51d4983a7d14f986206aa07292d63af581ff1a1e?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:203xxdlledLFnkqrUleD72'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq'},
#       'href': 'https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq',
#       'id': '2Hkut4rAAyrQxRdof7FVJq',
#       'name': 'Rush',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2xg7iIKoSqaDNpDbJnyCjY'},
#     'href': 'https://api.spotify.com/v1/albums/2xg7iIKoSqaDNpDbJnyCjY',
#     'id': '2xg7iIKoSqaDNpDbJnyCjY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27372833c1ae3343cbfb4617073',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0272833c1ae3343cbfb4617073',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485172833c1ae3343cbfb4617073',
#       'width': 64}],
#     'name': 'Moving Pictures (2011 Remaster)',
#     'release_date': '1981-02-12',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:2xg7iIKoSqaDNpDbJnyCjY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq'},
#      'href': 'https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq',
#      'id': '2Hkut4rAAyrQxRdof7FVJq',
#      'name': 'Rush',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Hkut4rAAyrQxRdof7FVJq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 276880,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMR18180103'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3QZ7uX97s82HFYSmQUAN1D'},
#    'href': 'https://api.spotify.com/v1/tracks/3QZ7uX97s82HFYSmQUAN1D',
#    'id': '3QZ7uX97s82HFYSmQUAN1D',
#    'is_local': False,
#    'name': 'Tom Sawyer',
#    'popularity': 70,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3QZ7uX97s82HFYSmQUAN1D'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#       'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#       'id': '2ye2Wgw4gimLv2eAKyk1NB',
#       'name': 'Metallica',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4bcUiX49wpmDRhrC8TvDWV'},
#     'href': 'https://api.spotify.com/v1/albums/4bcUiX49wpmDRhrC8TvDWV',
#     'id': '4bcUiX49wpmDRhrC8TvDWV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ee498e8074b8df8e375abe04',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ee498e8074b8df8e375abe04',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ee498e8074b8df8e375abe04',
#       'width': 64}],
#     'name': 'Hardwired…To Self-Destruct (Deluxe)',
#     'release_date': '2016-11-18',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4bcUiX49wpmDRhrC8TvDWV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#      'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#      'id': '2ye2Wgw4gimLv2eAKyk1NB',
#      'name': 'Metallica',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 350644,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMKHM1600380'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6F5RvdxWcLOJW7LAGuc24r'},
#    'href': 'https://api.spotify.com/v1/tracks/6F5RvdxWcLOJW7LAGuc24r',
#    'id': '6F5RvdxWcLOJW7LAGuc24r',
#    'is_local': False,
#    'name': 'Moth Into Flame',
#    'popularity': 52,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6F5RvdxWcLOJW7LAGuc24r'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/414jOqUfrq3k2QlAddNXfT'},
#     'href': 'https://api.spotify.com/v1/albums/414jOqUfrq3k2QlAddNXfT',
#     'id': '414jOqUfrq3k2QlAddNXfT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1886d236549fdbf0309b5ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1886d236549fdbf0309b5ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1886d236549fdbf0309b5ab',
#       'width': 64}],
#     'name': 'Lights...Camera...Revolution',
#     'release_date': '1990-07-02',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:414jOqUfrq3k2QlAddNXfT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 278306,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10022485'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1HvbGzyNAlohRQoOCknGaR'},
#    'href': 'https://api.spotify.com/v1/tracks/1HvbGzyNAlohRQoOCknGaR',
#    'id': '1HvbGzyNAlohRQoOCknGaR',
#    'is_local': False,
#    'name': "Go'n Breakdown",
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/53a227d8b2730754127354ee0e4dc1dc006b2b32?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:1HvbGzyNAlohRQoOCknGaR'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/316WHRzmIQfm65kyafcVVT'},
#     'href': 'https://api.spotify.com/v1/albums/316WHRzmIQfm65kyafcVVT',
#     'id': '316WHRzmIQfm65kyafcVVT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d032290e098e16533e6b9152',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d032290e098e16533e6b9152',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d032290e098e16533e6b9152',
#       'width': 64}],
#     'name': 'World Gone Mad',
#     'release_date': '2016-09-30',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:316WHRzmIQfm65kyafcVVT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AE',
#     'AR',
#     'AU',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'DO',
#     'DZ',
#     'EC',
#     'EG',
#     'GT',
#     'HK',
#     'HN',
#     'ID',
#     'IL',
#     'IN',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'MA',
#     'MX',
#     'MY',
#     'NI',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PS',
#     'PY',
#     'QA',
#     'SA',
#     'SG',
#     'SV',
#     'TH',
#     'TN',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 263618,
#    'explicit': True,
#    'external_ids': {'isrc': 'USA2P1666508'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1zUoTqwxreRK1I922sMNcD'},
#    'href': 'https://api.spotify.com/v1/tracks/1zUoTqwxreRK1I922sMNcD',
#    'id': '1zUoTqwxreRK1I922sMNcD',
#    'is_local': False,
#    'name': 'Clap Like Ozzy',
#    'popularity': 25,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ed378c5f83a64582f0776647d90a6fe1cf8e204b?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1zUoTqwxreRK1I922sMNcD'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0GRJggdZjtFQLzhznZvxFL'},
#     'href': 'https://api.spotify.com/v1/albums/0GRJggdZjtFQLzhznZvxFL',
#     'id': '0GRJggdZjtFQLzhznZvxFL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27365c0f381852055d9f40c01b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0265c0f381852055d9f40c01b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485165c0f381852055d9f40c01b6',
#       'width': 64}],
#     'name': "How Will I Laugh Tomorrow When I Can't Even Smile Today",
#     'release_date': '1988-09-02',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0GRJggdZjtFQLzhznZvxFL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 270693,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM18800102'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3jkg3492UhXZE378fyanq6'},
#    'href': 'https://api.spotify.com/v1/tracks/3jkg3492UhXZE378fyanq6',
#    'id': '3jkg3492UhXZE378fyanq6',
#    'is_local': False,
#    'name': 'Pledge Your Allegiance',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/04bf15e1e68e6b21e08789968145be5cd8b12bbf?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3jkg3492UhXZE378fyanq6'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6HKTApHHNPs9EmWrbPWnRl'},
#     'href': 'https://api.spotify.com/v1/albums/6HKTApHHNPs9EmWrbPWnRl',
#     'id': '6HKTApHHNPs9EmWrbPWnRl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738efc95b1d1e04e06d6ff25e9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028efc95b1d1e04e06d6ff25e9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518efc95b1d1e04e06d6ff25e9',
#       'width': 64}],
#     'name': 'Schizophrenia',
#     'release_date': '1987-10-30',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6HKTApHHNPs9EmWrbPWnRl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#      'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#      'id': '6JW8wliOEwaDZ231ZY7cf4',
#      'name': 'Sepultura',
#      'type': 'artist',
#      'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 274800,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA329780623'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5JKKTTmiIV1E0qWYZrEx61'},
#    'href': 'https://api.spotify.com/v1/tracks/5JKKTTmiIV1E0qWYZrEx61',
#    'id': '5JKKTTmiIV1E0qWYZrEx61',
#    'is_local': False,
#    'name': 'Septic Schizo - Rough Mix',
#    'popularity': 17,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ecfca4b39a70a44c499694374fbeeff0961b1cf1?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:5JKKTTmiIV1E0qWYZrEx61'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wWVKhxIU2cEi0K81v7HvP'},
#       'href': 'https://api.spotify.com/v1/artists/6wWVKhxIU2cEi0K81v7HvP',
#       'id': '6wWVKhxIU2cEi0K81v7HvP',
#       'name': 'Rammstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wWVKhxIU2cEi0K81v7HvP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/75OE7M0wduJyffbffehHuR'},
#     'href': 'https://api.spotify.com/v1/albums/75OE7M0wduJyffbffehHuR',
#     'id': '75OE7M0wduJyffbffehHuR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731108fef87966d83948b6a037',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021108fef87966d83948b6a037',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511108fef87966d83948b6a037',
#       'width': 64}],
#     'name': 'Zeit',
#     'release_date': '2022-04-29',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:75OE7M0wduJyffbffehHuR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wWVKhxIU2cEi0K81v7HvP'},
#      'href': 'https://api.spotify.com/v1/artists/6wWVKhxIU2cEi0K81v7HvP',
#      'id': '6wWVKhxIU2cEi0K81v7HvP',
#      'name': 'Rammstein',
#      'type': 'artist',
#      'uri': 'spotify:artist:6wWVKhxIU2cEi0K81v7HvP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 218593,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEUM72118410'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5KTBaWu8IOczQ0sPWzZ7MY'},
#    'href': 'https://api.spotify.com/v1/tracks/5KTBaWu8IOczQ0sPWzZ7MY',
#    'id': '5KTBaWu8IOczQ0sPWzZ7MY',
#    'is_local': False,
#    'name': 'Dicke Titten',
#    'popularity': 72,
#    'preview_url': None,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:5KTBaWu8IOczQ0sPWzZ7MY'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ZWj7yOC9Tstx1u55Qvcgq'},
#     'href': 'https://api.spotify.com/v1/albums/6ZWj7yOC9Tstx1u55Qvcgq',
#     'id': '6ZWj7yOC9Tstx1u55Qvcgq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273314838998f0bb5bb88362f80',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02314838998f0bb5bb88362f80',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851314838998f0bb5bb88362f80',
#       'width': 64}],
#     'name': "How Will I Laugh Tomorrow When I Can't Even Smile Today",
#     'release_date': '1988-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6ZWj7yOC9Tstx1u55Qvcgq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 272760,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAAA8800523'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5XEP010mCRtKxpd1ywyYAj'},
#    'href': 'https://api.spotify.com/v1/tracks/5XEP010mCRtKxpd1ywyYAj',
#    'id': '5XEP010mCRtKxpd1ywyYAj',
#    'is_local': False,
#    'name': 'Trip At The Brain',
#    'popularity': 34,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5XEP010mCRtKxpd1ywyYAj'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
# ...
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 229960,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA6P0800021'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7G83ZwD2msTtFaBQExc8QB'},
#    'href': 'https://api.spotify.com/v1/tracks/7G83ZwD2msTtFaBQExc8QB',
#    'id': '7G83ZwD2msTtFaBQExc8QB',
#    'is_local': False,
#    'name': 'Institutionalized',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8cbac47f4dab04ea29980bbb062c7c330a625be6?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7G83ZwD2msTtFaBQExc8QB'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hLSbWJ8HL8MUfIwrTP2EO'},
#     'href': 'https://api.spotify.com/v1/albums/4hLSbWJ8HL8MUfIwrTP2EO',
#     'id': '4hLSbWJ8HL8MUfIwrTP2EO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff66248fdc73fb872acf7087',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff66248fdc73fb872acf7087',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff66248fdc73fb872acf7087',
#       'width': 64}],
#     'name': 'Suicidal Tendencies',
#     'release_date': '1983',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4hLSbWJ8HL8MUfIwrTP2EO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 292800,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA6P0800024'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UEQ45wYDdFCvCDhRk6AbC'},
#    'href': 'https://api.spotify.com/v1/tracks/4UEQ45wYDdFCvCDhRk6AbC',
#    'id': '4UEQ45wYDdFCvCDhRk6AbC',
#    'is_local': False,
#    'name': 'I Saw Your Mommy...',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/84da001d94fafc308e5818854e74c533123e0980?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4UEQ45wYDdFCvCDhRk6AbC'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#       'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#       'id': '1w5Kfo2jwwIPruYS2UWh56',
#       'name': 'Pearl Jam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5zsDtoSrXK4usJ4MB1tCh2'},
#     'href': 'https://api.spotify.com/v1/albums/5zsDtoSrXK4usJ4MB1tCh2',
#     'id': '5zsDtoSrXK4usJ4MB1tCh2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a53f06a45b489abe8f577134',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a53f06a45b489abe8f577134',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a53f06a45b489abe8f577134',
#       'width': 64}],
#     'name': 'Yield',
#     'release_date': '1998-02-17',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5zsDtoSrXK4usJ4MB1tCh2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#      'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#      'id': '1w5Kfo2jwwIPruYS2UWh56',
#      'name': 'Pearl Jam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 231253,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19703251'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0dIipTYASaFwX1QxVrVFV7'},
#    'href': 'https://api.spotify.com/v1/tracks/0dIipTYASaFwX1QxVrVFV7',
#    'id': '0dIipTYASaFwX1QxVrVFV7',
#    'is_local': False,
#    'name': 'Do the Evolution',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/262ffcbf6befea769626293a7e768f3f8d5d281e?cid=2cdd2027043145eaad2b25adb580c2cd',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0dIipTYASaFwX1QxVrVFV7'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#       'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#       'id': '3WPKDlucMsXH6FC1XaclZC',
#       'name': 'Suicidal Tendencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hFbCALjmIxLU0wOVruSmy'},
#     'href': 'https://api.spotify.com/v1/albums/4hFbCALjmIxLU0wOVruSmy',
#     'id': '4hFbCALjmIxLU0wOVruSmy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735eb40d1db247cd3641164d3d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025eb40d1db247cd3641164d3d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515eb40d1db247cd3641164d3d',
#       'width': 64}],
#     'name': 'Join The Army',
#     'release_date': '1987',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4hFbCALjmIxLU0wOVruSmy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WPKDlucMsXH6FC1XaclZC'},
#      'href': 'https://api.spotify.com/v1/artists/3WPKDlucMsXH6FC1XaclZC',
#      'id': '3WPKDlucMsXH6FC1XaclZC',
#      'name': 'Suicidal Tendencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WPKDlucMsXH6FC1XaclZC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 230640,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN38700018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/03HL3jTzizrDNtPcmdPELp'},
#    'href': 'https://api.spotify.com/v1/tracks/03HL3jTzizrDNtPcmdPELp',
#    'id': '03HL3jTzizrDNtPcmdPELp',
#    'is_local': False,
#    'name': 'War Inside My Head',
#    'popularity': 47,
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:03HL3jTzizrDNtPcmdPELp'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CF71zaDOJWCynIkW9bSK8'},
#       'href': 'https://api.spotify.com/v1/artists/0CF71zaDOJWCynIkW9bSK8',
#       'id': '0CF71zaDOJWCynIkW9bSK8',
#       'name': 'White Zombie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0CF71zaDOJWCynIkW9bSK8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HugnfabsMODIbxzwxS5xC'},
#     'href': 'https://api.spotify.com/v1/albums/3HugnfabsMODIbxzwxS5xC',
#     'id': '3HugnfabsMODIbxzwxS5xC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2de49f423eb924c79a155d2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2de49f423eb924c79a155d2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2de49f423eb924c79a155d2',
#       'width': 64}],
#     'name': 'Astro Creep: 2000 Songs Of Love, Destruction And Other Synthetic Delusions Of The Electric Head',
#     'release_date': '1995',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3HugnfabsMODIbxzwxS5xC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CF71zaDOJWCynIkW9bSK8'},
#      'href': 'https://api.spotify.com/v1/artists/0CF71zaDOJWCynIkW9bSK8',
#      'id': '0CF71zaDOJWCynIkW9bSK8',
#      'name': 'White Zombie',
#      'type': 'artist',
#      'uri': 'spotify:artist:0CF71zaDOJWCynIkW9bSK8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HK',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 268760,
#    'explicit': True,
#    'external_ids': {'isrc': 'USGF19580608'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1NbJFhkVdD47YZ2IojKkJi'},
#    'href': 'https://api.spotify.com/v1/tracks/1NbJFhkVdD47YZ2IojKkJi',
#    'id': '1NbJFhkVdD47YZ2IojKkJi',
#    'is_local': False,
#    'name': 'More Human Than Human',
#    'popularity': 60,
#    'preview_url': None,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:1NbJFhkVdD47YZ2IojKkJi'}],
#  'total': 50,
#  'limit': 20,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=20&offset=20&time_range=short_term',
#  'previous': None}

# %%
def get_tracks_id(time_frame):
    track_ids=[]
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
tracks_ids = get_tracks_id(top_tracks_short)
tracks_ids
# Out:
# ['0q94IE56HxyHAsVnJ4bmPF',
#  '2hutxDJDHUWlYlHbq4oReO',
#  '0dwoX2gsjlRNa3rS40KFhQ',
#  '0Nd9G2HD0u3ca7PPtf0Olp',
#  '203xxdlledLFnkqrUleD72',
#  '3QZ7uX97s82HFYSmQUAN1D',
#  '6F5RvdxWcLOJW7LAGuc24r',
#  '1HvbGzyNAlohRQoOCknGaR',
#  '1zUoTqwxreRK1I922sMNcD',
#  '3jkg3492UhXZE378fyanq6',
#  '5JKKTTmiIV1E0qWYZrEx61',
#  '5KTBaWu8IOczQ0sPWzZ7MY',
#  '5XEP010mCRtKxpd1ywyYAj',
#  '6GulNC8embtfc0T8EyC7GB',
#  '6M9LS6qCM9o6IlXFClD7OT',
#  '7G83ZwD2msTtFaBQExc8QB',
#  '4UEQ45wYDdFCvCDhRk6AbC',
#  '0dIipTYASaFwX1QxVrVFV7',
#  '03HL3jTzizrDNtPcmdPELp',
#  '1NbJFhkVdD47YZ2IojKkJi']

# %%
def get_track_features(id):
    meta = sp.track(id)
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name,album,artist,spotify_url,album_cover]
    return track_info

# %%
get_track_features('1NbJFhkVdD47YZ2IojKkJi')
# Out:
# ['More Human Than Human',
#  'Astro Creep: 2000 Songs Of Love, Destruction And Other Synthetic Delusions Of The Electric Head',
#  'White Zombie',
#  'https://open.spotify.com/track/1NbJFhkVdD47YZ2IojKkJi',
#  'https://i.scdn.co/image/ab67616d0000b273d2de49f423eb924c79a155d2']

# %%
tracks = []
for i in range(len(tracks_ids)):
    time.sleep(.5)
    track = get_track_features(tracks_ids[i])
    tracks.append(track)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 for i in range(len(tracks_ids)):
#       3     time.sleep(.5)
# ----> 4     track = get_track_features(tracks_ids[i])
#       5     tracks.append(track)
#
# Cell In[13], line 2, in get_track_features(id)
#       1 def get_track_features(id):
# ----> 2     meta = sp.track(id)
#       3     name = meta['name']
#       4     album = meta['album']['name']
#
# File c:\Users\ddrod01.CO\AppData\Local\Programs\Python\Python311\Lib\site-packages\spotipy\client.py:368, in Spotify.track(self, track_id, market)
#     360 def track(self, track_id, market=None):
#     361     """ returns a single track given the track's ID, URI or URL
#     362
#     363         Parameters:
#     364             - track_id - a spotify URI, URL or ID
#     365             - market - an ISO 3166-1 alpha-2 country code.
#     366     """
# --> 368     trid = self._get_id("track", track_id)
#     369     return self._get("tracks/" + trid, market=market)
#
# File c:\Users\ddrod01.CO\AppData\Local\Programs\Python\Python311\Lib\site-packages\spotipy\client.py:1967, in Spotify._get_id(self, type, id)
#    1966 def _get_id(self, type, id):
# -> 1967     uri_match = re.search(Spotify._regex_spotify_uri, id)
#    1968     if uri_match is not None:
#    1969         uri_match_groups = uri_match.groupdict()
#
# File c:\Users\ddrod01.CO\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'NoneType'

# %%
tracks
# Out:
# [['Institutionalized 2014',
#   'Manslaughter',
#   'Body Count',
#   'https://open.spotify.com/track/0q94IE56HxyHAsVnJ4bmPF',
#   'https://i.scdn.co/image/ab67616d0000b273d7cb25a30d1b17177e33539a'],
#  ['How Will I Laugh Tomorrow - Video Edit',
#   'Controlled By Hatred/Feel Like Shit... Deja-Vu',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/2hutxDJDHUWlYlHbq4oReO',
#   'https://i.scdn.co/image/ab67616d0000b2735eeeb898d246bbbd3027c401'],
#  ['Screaming Suicide',
#   'Screaming Suicide',
#   'Metallica',
#   'https://open.spotify.com/track/0dwoX2gsjlRNa3rS40KFhQ',
#   'https://i.scdn.co/image/ab67616d0000b2738a3496e652b26ed82cc9b5ff'],
#  ['Waking the Dead',
#   'Controlled By Hatred/Feel Like Shit... Deja-Vu',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/0Nd9G2HD0u3ca7PPtf0Olp',
#   'https://i.scdn.co/image/ab67616d0000b2735eeeb898d246bbbd3027c401'],
#  ["You Can't Bring Me Down",
#   'Lights...Camera...Revolution',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/203xxdlledLFnkqrUleD72',
#   'https://i.scdn.co/image/ab67616d0000b273d1886d236549fdbf0309b5ab'],
#  ['Tom Sawyer',
#   'Moving Pictures (2011 Remaster)',
#   'Rush',
#   'https://open.spotify.com/track/3QZ7uX97s82HFYSmQUAN1D',
#   'https://i.scdn.co/image/ab67616d0000b27372833c1ae3343cbfb4617073'],
#  ['Moth Into Flame',
#   'Hardwired…To Self-Destruct (Deluxe)',
#   'Metallica',
#   'https://open.spotify.com/track/6F5RvdxWcLOJW7LAGuc24r',
#   'https://i.scdn.co/image/ab67616d0000b273ee498e8074b8df8e375abe04'],
#  ["Go'n Breakdown",
#   'Lights...Camera...Revolution',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/1HvbGzyNAlohRQoOCknGaR',
#   'https://i.scdn.co/image/ab67616d0000b273d1886d236549fdbf0309b5ab'],
#  ['Clap Like Ozzy',
#   'World Gone Mad',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/1zUoTqwxreRK1I922sMNcD',
#   'https://i.scdn.co/image/ab67616d0000b273d032290e098e16533e6b9152'],
#  ['Pledge Your Allegiance',
#   "How Will I Laugh Tomorrow When I Can't Even Smile Today",
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/3jkg3492UhXZE378fyanq6',
#   'https://i.scdn.co/image/ab67616d0000b27365c0f381852055d9f40c01b6'],
#  ['Septic Schizo - Rough Mix',
#   'Schizophrenia',
#   'Sepultura',
#   'https://open.spotify.com/track/5JKKTTmiIV1E0qWYZrEx61',
#   'https://i.scdn.co/image/ab67616d0000b2738efc95b1d1e04e06d6ff25e9'],
#  ['Dicke Titten',
#   'Zeit',
#   'Rammstein',
#   'https://open.spotify.com/track/5KTBaWu8IOczQ0sPWzZ7MY',
#   'https://i.scdn.co/image/ab67616d0000b2731108fef87966d83948b6a037'],
#  ['Trip At The Brain',
#   "How Will I Laugh Tomorrow When I Can't Even Smile Today",
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/5XEP010mCRtKxpd1ywyYAj',
#   'https://i.scdn.co/image/ab67616d0000b273314838998f0bb5bb88362f80'],
#  ['Gotta Kill Captain Stupid',
#   'The Art Of Rebellion',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/6GulNC8embtfc0T8EyC7GB',
#   'https://i.scdn.co/image/ab67616d0000b2739cd5a44ba1982f4739b4f1c9'],
#  ['Join The New Army',
#   'Prime Cuts',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/6M9LS6qCM9o6IlXFClD7OT',
#   'https://i.scdn.co/image/ab67616d0000b2736376e436178947e28a46a3d1'],
#  ['Institutionalized',
#   'Suicidal Tendencies',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/7G83ZwD2msTtFaBQExc8QB',
#   'https://i.scdn.co/image/ab67616d0000b273ff66248fdc73fb872acf7087'],
#  ['I Saw Your Mommy...',
#   'Suicidal Tendencies',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/4UEQ45wYDdFCvCDhRk6AbC',
#   'https://i.scdn.co/image/ab67616d0000b273ff66248fdc73fb872acf7087'],
#  ['Do the Evolution',
#   'Yield',
#   'Pearl Jam',
#   'https://open.spotify.com/track/0dIipTYASaFwX1QxVrVFV7',
#   'https://i.scdn.co/image/ab67616d0000b273a53f06a45b489abe8f577134'],
#  ['War Inside My Head',
#   'Join The Army',
#   'Suicidal Tendencies',
#   'https://open.spotify.com/track/03HL3jTzizrDNtPcmdPELp',
#   'https://i.scdn.co/image/ab67616d0000b2735eb40d1db247cd3641164d3d'],
#  ['More Human Than Human',
#   'Astro Creep: 2000 Songs Of Love, Destruction And Other Synthetic Delusions Of The Electric Head',
#   'White Zombie',
#   'https://open.spotify.com/track/1NbJFhkVdD47YZ2IojKkJi',
#   'https://i.scdn.co/image/ab67616d0000b273d2de49f423eb924c79a155d2']]

# %%
df = pd.DataFrame(tracks, columns=['name','album','artist','spotify_url','album_cover'])
df.head(5)
# Out:
#                                      name  \
# 0                  Institutionalized 2014
# 1  How Will I Laugh Tomorrow - Video Edit
# 2                       Screaming Suicide
# 3                         Waking the Dead
# 4                 You Can't Bring Me Down
#
#                                             album               artist  \
# 0                                    Manslaughter           Body Count
# 1  Controlled By Hatred/Feel Like Shit... Deja-Vu  Suicidal Tendencies
# 2                               Screaming Suicide            Metallica
# 3  Controlled By Hatred/Feel Like Shit... Deja-Vu  Suicidal Tendencies
# 4                    Lights...Camera...Revolution  Suicidal Tendencies
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/0q94IE56HxyHAsV...
# 1  https://open.spotify.com/track/2hutxDJDHUWlYlH...
# 2  https://open.spotify.com/track/0dwoX2gsjlRNa3r...
# 3  https://open.spotify.com/track/0Nd9G2HD0u3ca7P...
# 4  https://open.spotify.com/track/203xxdlledLFnkq...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b273d7cb25...
# 1  https://i.scdn.co/image/ab67616d0000b2735eeeb8...
# 2  https://i.scdn.co/image/ab67616d0000b2738a3496...
# 3  https://i.scdn.co/image/ab67616d0000b2735eeeb8...
# 4  https://i.scdn.co/image/ab67616d0000b273d1886d...

# %%
df.to_csv('Spotify_Wrap.csv',index=False)
