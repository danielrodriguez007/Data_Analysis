# %% [markdown]
# <a href="https://colab.research.google.com/github/danielrodriguez007/Data_Analysis/blob/main/Pie_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
data = [20, 50 , 30, 60]
plt.figure(figsize=(10,8))
plt.pie(data)
plt.show()

# %%
df = pd.read_json('https://raw.githubusercontent.com/amankharwal/Website-data/master/datanew.json')
group_size = [sum(df.positive), sum(df.active), sum(df.cured)] 
group_labels = ["Positive\n" +str(sum(df.positive)),
                "Active\n" +str(sum(df.active)),
                "Cured\n" +str(sum(df.cured)),]
custom_colors = ["skyblue", "yellowgreen", "tomato"]
plt.figure(figsize=(10,8))
plt.pie(group_size, colors = custom_colors, labels=group_labels)
plt.rc('font', size=12) 
plt.title('Total Positive, Active, and Cured Cases', fontsize=20)
plt.show()

# %%
df.drop(df.tail(1).index, inplace = True)
df1 = df.sort_values(by='active', ascending=False)
df3 = df1[:5]
states = df3.state_name 
active = df3.active 

plt.figure(figsize=(10,8))
plt.pie(active, labels=states)
plt.rc('font', size=12)
plt.title('Top 5 Active cases', fontsize=20)
plt.show()

# %%
from enum import auto
data = [50,10,25,15]
labels = ['Grape', 'BlueBerry', 'StrawBerry', 'Mango']
colors = ['#6f2da8','#4f86f7', '#fc5a8d', '#F4BB44' ]
explode = [0,0,0.1,0]


plt.figure(figsize=(15,10))
plt.pie(data, labels=labels,colors = colors, shadow=True,  autopct= '%.1f%%', explode = explode, startangle =90)
plt.title('Fruits more saled', fontsize=30)
plt.show()
